# %%
# connect to google drive
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# move to folder with required files
# %cd /content/gdrive/MyDrive/ColabFiles/KursFiles
# Out:
# /content/gdrive/MyDrive/ColabFiles/KursFiles

# %%
# download python 3.12+ for neosr
# !sudo apt-get update -y
# !sudo apt-get install python3.12
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,681 kB]
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,237 kB]
# ...

# %%
# add python 3.12 to path
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.12 1

# %%
# install poetry for neosr
# !pip -q install poetry
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.7/277.7 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.2/331.2 kB 25.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 33.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.3/53.3 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 95.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 34.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 35.7 MB/s eta 0:00:00

# %%
# check if poetry installed correctly
# !poetry --version
# Out:
# Poetry (version 2.1.1)

# %%
# clone neosr project form github (if it has not been done before) and with poetry install neosr dependencies
# !git clone https://github.com/neosr-project/neosr
# %cd neosr
# !poetry install --sync
# Out:
# fatal: destination path 'neosr' already exists and is not an empty directory.
# /content/gdrive/MyDrive/ColabFiles/KursFiles/neosr
# The currently activated Python version 3.11.11 is not supported by the project (^3.12,<3.13).
# Trying to find and use a compatible version.
# Using python3.12 (3.12.9)
# Creating virtualenv neosr-KaUXh9cQ-py3.12 in /root/.cache/pypoetry/virtualenvs
# The `--sync` option is deprecated and slated for removal in the next minor release after June 2025, use the `poetry sync` command instead.
# Installing dependencies from lock file
#
# Package operations: 47 installs, 0 updates, 0 removals
#
#   - Installing nvidia-nvjitlink-cu12 (12.4.127): Pending...
#   - Installing nvidia-nvjitlink-cu12 (12.4.127): Downloading... 0%
#   - Installing nvidia-nvjitlink-cu12 (12.4.127): Downloading... 20%
#   - Installing nvidia-nvjitlink-cu12 (12.4.127): Downloading... 60%
#   - Installing nvidia-nvjitlink-cu12 (12.4.127): Downloading... 100%
# ...

# %%
# start (or resume) training with set configuration
#
#Configurarion to train esrgan network on Total-Text-Dataset on pretrained 4xNomosWebPhoto_esrgan model
# !poetry run python train.py -opt options/4xNomosWebPhoto_TotalText_esrgan/train_4xNomosWebPhoto_TotalText_esrgan.toml --auto_resume
#!poetry run python train.py -opt options/4xNomosWebPhoto_TotalText_esrgan/train_4xNomosWebPhoto_TotalText_esrgan.toml
# Out:
# The currently activated Python version 3.11.11 is not supported by the project (^3.12,<3.13).
# Trying to find and use a compatible version.
# Using python3.12 (3.12.9)
# NOTICE: pretrain_network_* is ignored during resuming.
# 22-03-2025 07:10 PM | INFO:
# ------------------------ neosr ------------------------
# Pytorch Version: 2.5.1+cu124. Running on gpu Tesla T4, with driver 550.54.15.
# 22-03-2025 07:10 PM | INFO: Dataset [paired] is built.
# /root/.cache/pypoetry/virtualenvs/neosr-KaUXh9cQ-py3.12/lib/python3.12/site-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ...
